# %%
import numpy as np
import scipy.linalg as LA
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# 1. load data
data_dir = 'C:\\Users\\ChienYu\\Downloads\\ml_data'
D = np.loadtxt(data_dir + '\\la_2.txt' ,comments='%')
# 2. Scatter plot
# −−− define attributes for the scatter plot
s = 30 # define the size of markers
# define the colors of markers according to group value 0, 1
# colors = D[:,2]
# colors = [’red’ if i == 0 else ’blue’ for i in D[:,2]]

colors = [[1,0,0] if i == 0 else [0,0,1] for i in D[:,2]]
plt.scatter(D[:,0], D[:,1], s=s, c=colors,alpha=0.5, marker="o")
plt.grid(True)

#to add legend to scatter plot
pop_a = mpatches.Patch(color=[1, 0, 0],alpha=0.5, label='Group A')
pop_b = mpatches.Patch(color=[0, 0, 1],alpha=0.5, label='Group B')
plt.legend(handles=[pop_a,pop_b])
n = len(D[:, 0])
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
b = LA.inv(X.T @ X) @ X.T @ y.T
# Draw a linear regression line
x = np.array([1.5, 4.5])
y = -(b[0] - 0.5 + b[1] * x) / b[2]
plt.plot(x, y, lw=3)
plt.show()

# %%
import numpy as np
import scipy.linalg as LA
import matplotlib.pyplot as plt
# 1. load data
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_2.txt', comments='%')
# 2. Scatter plot
# −−− define attributes for the scatter plot
s = 30 # define the size of markers
# define the colors of markers according to group value 0, 1
# colors = D[:,2]
# colors = [’red’ if i == 0 else ’blue’ for i in D[:,2]]
colors = [[1,0,0] if i == 0 else [0,0,1] for i in D[:,2]]
plt.scatter(D[:, 0], D[:, 1], c = colors, s = s, \
marker = 'o', alpha = 0.5)
plt.grid(True)

plt.show()

# %%
import numpy as np
import scipy.linalg as LA
import matplotlib.pyplot as plt
# 1. load data
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_1.txt', comments='%')
# 2. Scatter plot
# −−− define attributes for the scatter plot
s = 30 # define the size of markers
# define the colors of markers according to group value 0, 1
# colors = D[:,2]
# colors = [’red’ if i == 0 else ’blue’ for i in D[:,2]]
colors = [[1,0,0] if i == 0 else [0,0,1] for i in D[:,2]]
plt.scatter(D[:, 0], D[:, 1], c = colors, s = s, \
marker = 'o', alpha = 0.5)

n = len(D[:, 0])
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
b = LA.inv(X.T @ X) @ X.T @ y.T
# Draw a linear regression line
x = np.array([1.5, 4.5])
y = -(b[0] - 0.5 + b[1] * x) / b[2]
plt.plot(x, y, lw=3)
plt.show()

# %%
import numpy as np
import scipy.linalg as LA
import matplotlib.pyplot as plt
# 1. load data
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_2.txt', comments='%')
# 2. Scatter plot
# −−− define attributes for the scatter plot
s = 30 # define the size of markers
# define the colors of markers according to group value 0, 1
# colors = D[:,2]
# colors = [’red’ if i == 0 else ’blue’ for i in D[:,2]]
colors = [[1,0,0] if i == 0 else [0,0,1] for i in D[:,2]]
plt.scatter(D[:, 0], D[:, 1], c = colors, s = s, \
marker = 'o', alpha = 0.5)

n = len(D[:, 0])
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
b = LA.inv(X.T @ X) @ X.T @ y.T
# Draw a linear regression line
x = np.array([1.5, 4.5])
y = -(b[0] - 0.5 + b[1] * x) / b[2]
plt.plot(x, y, lw=3)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import scipy.linalg as LA
import matplotlib.pyplot as plt
# 1. load data
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_3.txt', comments='%')
# 2. Scatter plot
# −−− define attributes for the scatter plot
s = 30 # define the size of markers
# define the colors of markers according to group value 0, 1
# colors = D[:,2]
# colors = [’red’ if i == 0 else ’blue’ for i in D[:,2]]
colors = [[1,0,0] if i == 0 else [0,0,1] for i in D[:,2]]
plt.scatter(D[:, 0], D[:, 1], c = colors, s = s, \
marker = 'o', alpha = 0.5)

n = len(D[:, 0])
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]

# Linear Regression by sklearn
Mdl = LinearRegression()# 建立新的 linear regression model
Mdl.fit(X, y) # 進行估計 （ 配適 ）
# R2 = Mdl.score(X, y) # R−square
intrcp = Mdl.intercept_ # 估計結果 ：beta0
coeffs = Mdl.coef_ # # 估計結果 ：beta1, beta2, ...
# Draw a regression line
x = np.array([-3, 5])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
plt.plot(x, f, lw=3)
# Calculate testing error
y_hat = Mdl.predict(X) # 預 測 或 計 算 擬 合 值
y_pre = [1 if i > 0.5 else 0 for i in y_hat] # 群組判讀
plt.title("Accuracy in training is {:.2f}".format( \
    100 * np.mean(y_pre == y)))
plt.xlabel("$X_1$"), plt.ylabel("$X_2$")
plt.show()

# %%
#Simple linear regression model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_2.txt', comments='%')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo', \
    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
b = LA.inv(X.T @ X) @ X.T @ y.T
x= np.array([x_min, x_max])
y = (0.5-b[0]-b[1]*x)/b[2]
plt.plot(x, y, 'k-', label = 'Linear Regression')
plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
#Simple linear regression model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_2.txt', comments='%')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo', \
    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
# b = LA.inv(X.T @ X) @ X.T @ y.T
# x= np.array([x_min, x_max])
# y = (0.5-b[0]-b[1]*x)/b[2]
# plt.plot(x, y, 'k-', label = 'Linear Regression')

Mdl = LinearRegression()
Mdl.fit(X, y) 

intrcp = Mdl.intercept_ #beta_0
coeffs = Mdl.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
plt.plot(x, f, lw=3)
y_hat = Mdl.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.title('Accuracy in training is {:.2f}%'.format( \
100 * np.mean(y_pre == y)))
plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
#Simple linear, Augmented regression model import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_3.txt', comments='%')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo',    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
# b = LA.inv(X.T @ X) @ X.T @ y.T
# x= np.array([x_min, x_max])
# y = (0.5-b[0]-b[1]*x)/b[2]
# plt.plot(x, y, 'k-', label = 'Linear Regression')

Mdl = LinearRegression()
Mdl.fit(X, y) 

intrcp = Mdl.intercept_ #beta_0
coeffs = Mdl.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
y_hat = Mdl.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, lw=3)
plt.title('Accuracy in training is {:.2f}%'.format( \
100 * np.mean(y_pre == y)))

x1 = D[:, 0:1] # n x 1 vector
x2 = D[:, 1:2]
X = np.hstack((np.ones((n, 1)), \
x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
b = LA.pinv(X) @ y
f = (
lambda x: b[0]
+ b[1] * x[0]
+ b[2] * x[1]
+ b[3] * x[0] * x[1]
+ b[4] * x[0] ** 2
+ b[5] * x[1] ** 2)
nx=ny=200
xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])

contours = plt.contour(
XX, YY, Z, levels = [0.5], colors='g', linestyles='--')
plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
#Simple linear, Augmented regression model  #有算錯誤率
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_3.txt', comments='%')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo', \
    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
# b = LA.inv(X.T @ X) @ X.T @ y.T
# x= np.array([x_min, x_max])
# y = (0.5-b[0]-b[1]*x)/b[2]
# plt.plot(x, y, 'k-', label = 'Linear Regression')

Mdl = LinearRegression()
Mdl.fit(X, y) 

intrcp = Mdl.intercept_ #beta_0
coeffs = Mdl.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
y_hat = Mdl.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, lw=3 ,label = '{:.4f}'.format(1 - np.mean(y_pre == y)) )
plt.title('Accuracy in training is {:.2f}%'.format( \
100 * np.mean(y_pre == y)))

x1 = D[:, 0:1] # n x 1 vector
x2 = D[:, 1:2]
X = np.hstack((np.ones((n, 1)), \
x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
# b = LA.pinv(X) @ y
# f = (
# lambda x: b[0]
# + b[1] * x[0]
# + b[2] * x[1]
# + b[3] * x[0] * x[1]
# + b[4] * x[0] ** 2
# + b[5] * x[1] ** 2)
Mda = LinearRegression()
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
coeffs = Mda.coef_
intrcp = Mda.intercept_
f = (
lambda x: intrcp 
+ Mda.coef_[1] * x[0]
+ Mda.coef_[2] * x[1]
+ Mda.coef_[3] * x[0] * x[1]
+ Mda.coef_[4] * x[0] ** 2
+ Mda.coef_[5] * x[1] ** 2)
nx=ny=200
xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])

contours = plt.contour(
XX, YY, Z, levels = [0.5], colors='#BE77FF', linestyles='--')
contours.collections[0].set_label(\
'{:.4f}'.format(1 - np.mean(y_pre == y)))
plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
#Simple linear, Augmented regression model, Logistic Regression model #有算錯誤率
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/ml_data/'
D = np.loadtxt(data_dir + 'la_3.txt', comments='%')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo', \
    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
# b = LA.inv(X.T @ X) @ X.T @ y.T
# x= np.array([x_min, x_max])
# y = (0.5-b[0]-b[1]*x)/b[2]
# plt.plot(x, y, 'k-', label = 'Linear Regression')

Mdl = LinearRegression()
Mdl.fit(X, y) 

intrcp = Mdl.intercept_ #beta_0
coeffs = Mdl.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
y_hat = Mdl.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, lw=3 ,label = '{:.4f}'.format(1 - np.mean(y_pre == y)) )
plt.title('Accuracy in training is {:.2f}%'.format( \
100 * np.mean(y_pre == y)))

x1 = D[:, 0:1] # n x 1 vector
x2 = D[:, 1:2]
X = np.hstack((np.ones((n, 1)), \
x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
# b = LA.pinv(X) @ y
# f = (
# lambda x: b[0]
# + b[1] * x[0]
# + b[2] * x[1]
# + b[3] * x[0] * x[1]
# + b[4] * x[0] ** 2
# + b[5] * x[1] ** 2)
Mda = LinearRegression()
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
coeffs = Mda.coef_
intrcp = Mda.intercept_
f = (
lambda x: intrcp 
+ Mda.coef_[1] * x[0]
+ Mda.coef_[2] * x[1]
+ Mda.coef_[3] * x[0] * x[1]
+ Mda.coef_[4] * x[0] ** 2
+ Mda.coef_[5] * x[1] ** 2)
nx=ny=200
xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])

contours = plt.contour(
XX, YY, Z, levels = [0.5], colors='g', linestyles='--')
contours.collections[0].set_label(\
'{:.4f}'.format(1 - np.mean(y_pre == y)))

Mdb = LogisticRegression()
Mdb.fit(X, y)
intrcp = Mdb.intercept_ #alpha
coeffs = Mdb.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f=(-intrcp - coeffs[0,1] * x) / coeffs[0,2]
y_hat = Mdb.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, 'k-', lw=3, label = '{:.4f}'.format(1 - np.mean(y_pre == y)))

plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
import numpy as np

# 設定隨機種子以便重現結果
np.random.seed(42)

# 生成200筆X1和X2數據
X1 = np.random.uniform(low=-5, high=5, size=200).round(20)
X2 = np.random.uniform(low=-3, high=4, size=200).round(20)

# 生成對應的Y
Y = np.random.randint(0, 2, size=200)

# 顯示前10筆資料
for i in range(10):
    print(f"X1: {X1[i]}, X2: {X2[i]}, Y: {Y[i]}")
# Out:
# X1: -1.254598811526375, X2: 1.4942215230800144, Y: 0
# X1: 4.507143064099161, X2: -2.411020245034658, Y: 1
# X1: 2.3199394181140507, X2: -1.8685990013377036, Y: 0
# X1: 0.986584841970366, X2: 3.289879319689555, Y: 0
# X1: -3.439813595575635, X2: 1.2450034176171298, Y: 1
# X1: -3.4400547966379733, X2: -2.9356206386835924, Y: 1
# X1: -4.419163878318005, X2: -2.2896991999377754, Y: 1
# X1: 3.6617614577493516, X2: 1.6445123837563909, Y: 0
# X1: 1.0111501174320878, X2: -2.964568913076469, Y: 1
# X1: 2.0807257779604544, X2: -1.8743436400775093, Y: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 設定隨機種子以確保結果可重複
np.random.seed(1)

# 生成特徵值 x1 和 x2
num_samples = 200
x1 = np.random.normal(-5, 5, num_samples)
x2 = np.random.normal(-3, 4, num_samples)
X= np.array([x1, x2]).T
# 生成隨機的 Y 值（二元目標）
# 這裡使用簡單的邏輯條件來產生 Y 值，你可以根據實際需求進行修改
Y = (2 * x1 - 3 * x2 + np.random.normal(0, 0.5, num_samples)) > 0

# 合併數據
data = np.column_stack((X1, X2, Y))

# 保存為txt文件
np.savetxt('data_y.txt', data, fmt='%.20f', delimiter='\t')

# %%
import numpy as np

# 設定隨機種子以便重現結果
np.random.seed(42)

# 生成200筆X1和X2數據
X1 = np.random.uniform(low=-5, high=5, size=200).round(20)
X2 = np.random.uniform(low=-3, high=4, size=200).round(20)

# 生成對應的Y
Y = np.random.randint(0, 2, size=200)

# 合併數據
data = np.column_stack((X1, X2, Y))

# 保存為txt文件
np.savetxt('data.txt', data, fmt='%.20f', delimiter='\t')

# %%
#Simple linear, Augmented regression model, Logistic Regression model #有算錯誤率
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/python 統計應用/'
D = np.loadtxt(data_dir + 'data.txt')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo', \
    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
# b = LA.inv(X.T @ X) @ X.T @ y.T
# x= np.array([x_min, x_max])
# y = (0.5-b[0]-b[1]*x)/b[2]
# plt.plot(x, y, 'k-', label = 'Linear Regression')

Mdl = LinearRegression()
Mdl.fit(X, y) 

intrcp = Mdl.intercept_ #beta_0
coeffs = Mdl.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
y_hat = Mdl.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, lw=3 ,label = '{:.4f}'.format(1 - np.mean(y_pre == y)) )
plt.title('Accuracy in training is {:.2f}%'.format( \
100 * np.mean(y_pre == y)))

x1 = D[:, 0:1] # n x 1 vector
x2 = D[:, 1:2]
X = np.hstack((np.ones((n, 1)), \
x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
# b = LA.pinv(X) @ y
# f = (
# lambda x: b[0]
# + b[1] * x[0]
# + b[2] * x[1]
# + b[3] * x[0] * x[1]
# + b[4] * x[0] ** 2
# + b[5] * x[1] ** 2)
Mda = LinearRegression()
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
coeffs = Mda.coef_
intrcp = Mda.intercept_
f = (
lambda x: intrcp 
+ Mda.coef_[1] * x[0]
+ Mda.coef_[2] * x[1]
+ Mda.coef_[3] * x[0] * x[1]
+ Mda.coef_[4] * x[0] ** 2
+ Mda.coef_[5] * x[1] ** 2)
nx=ny=200
xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])

contours = plt.contour(
XX, YY, Z, levels = [0.5], colors='g', linestyles='--')
contours.collections[0].set_label(\
'{:.4f}'.format(1 - np.mean(y_pre == y)))

Mdb = LogisticRegression()
Mdb.fit(X, y)
intrcp = Mdb.intercept_ #alpha
coeffs = Mdb.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f=(-intrcp - coeffs[0,1] * x) / coeffs[0,2]
y_hat = Mdb.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, 'k-', lw=3, label = '{:.4f}'.format(1 - np.mean(y_pre == y)))

plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
#Simple linear, Augmented regression model, Logistic Regression model #有算錯誤率
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy.linalg as LA
data_dir = 'C:/Users/ChienYu/Downloads/python 統計應用/'
D = np.loadtxt(data_dir + 'data_y.txt')
s = 30
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
Idx = (D[:,2]==0)
plt.plot(D[Idx, 0], D[Idx, 1], 'ro',\
alpha = 0.5, label = 'Group A')
Idx = (D[:,2]==1)
plt.plot(D[Idx,0], D[Idx,1],'bo', \
    alpha = 0.5, label = 'Group B')

n = len(D[:, 0])# number of samples
X = np.hstack((np.ones((n, 1)), D[:, 0:2]))
y = D[:, 2]
# b = LA.inv(X.T @ X) @ X.T @ y.T
# x= np.array([x_min, x_max])
# y = (0.5-b[0]-b[1]*x)/b[2]
# plt.plot(x, y, 'k-', label = 'Linear Regression')

Mdl = LinearRegression()
Mdl.fit(X, y) 

intrcp = Mdl.intercept_ #beta_0
coeffs = Mdl.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f = -(intrcp - 0.5 + coeffs[1] * x) / coeffs[2]
y_hat = Mdl.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, lw=3 ,label = '{:.4f}'.format(1 - np.mean(y_pre == y)) )
plt.title('Accuracy in training is {:.2f}%'.format( \
100 * np.mean(y_pre == y)))

x1 = D[:, 0:1] # n x 1 vector
x2 = D[:, 1:2]
X = np.hstack((np.ones((n, 1)), \
x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
# b = LA.pinv(X) @ y
# f = (
# lambda x: b[0]
# + b[1] * x[0]
# + b[2] * x[1]
# + b[3] * x[0] * x[1]
# + b[4] * x[0] ** 2
# + b[5] * x[1] ** 2)
Mda = LinearRegression()
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
coeffs = Mda.coef_
intrcp = Mda.intercept_
f = (
lambda x: intrcp 
+ Mda.coef_[1] * x[0]
+ Mda.coef_[2] * x[1]
+ Mda.coef_[3] * x[0] * x[1]
+ Mda.coef_[4] * x[0] ** 2
+ Mda.coef_[5] * x[1] ** 2)
nx=ny=200
xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])

contours = plt.contour(
XX, YY, Z, levels = [0.5], colors='g', linestyles='--')
contours.collections[0].set_label(\
'{:.4f}'.format(1 - np.mean(y_pre == y)))

Mdb = LogisticRegression()
Mdb.fit(X, y)
intrcp = Mdb.intercept_ #alpha
coeffs = Mdb.coef_  #beta_1, beta_2
x = np.array([x_min, x_max])
f=(-intrcp - coeffs[0,1] * x) / coeffs[0,2]
y_hat = Mdb.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
plt.plot(x, f, 'k-', lw=3, label = '{:.4f}'.format(1 - np.mean(y_pre == y)))

plt.ylim(y_min, y_max)
plt.legend(), plt.grid(True)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
# Out:
# Text(0, 0.5, '$X_2$')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]


plt.grid(True)
plt.legend()
plt.savefig('plot_1.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-2,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, 0.9], [0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

plt.axvspan(-20, 10, facecolor='#DDDDFF', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#DDDDFF', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_2.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-12,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, 0.9], [0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

plt.axvspan(-20, 10, facecolor='#DDDDFF', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#DDDDFF', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_3.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[15, 5], [5, 10]])
Cov2 = np.array([[1, 0], [0, 1]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')
n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

plt.axvspan(-20, 10, facecolor='#B3D9D9', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#B3D9D9', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_4.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[2, 1], [1, 1]])
Cov2 = np.array([[18, -3], [-3, 6]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')
n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

plt.axvspan(-20, 10, facecolor='#B3D9D9', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#B3D9D9', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_5.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-4,2]), np.array([2, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[10, 1.2], [1.2, 2.3]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

plt.axvspan(-20, 10, facecolor='#EBD6D6', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#EBD6D6', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_6.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([-3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[10, 1.2], [1.2, 2.3]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

plt.axvspan(-20, 10, facecolor='#EBD6D6', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#EBD6D6', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_7.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 400, 20
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[6, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, 0.9], [0.9, 3.9]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

plt.axvspan(-20, 10, facecolor='#FFED97', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#FFED97', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_8.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 300, 800
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[6, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, 0.9], [0.9, 3.9]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

plt.axvspan(-20, 10, facecolor='#FFED97', alpha=0.3)
plt.axhspan(-5, 10, facecolor='#FFED97', alpha=0.3)

plt.grid(True)
plt.legend()
plt.xlim(-20, 10)
plt.ylim(-5, 10)
plt.savefig('plot_9.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#0080FF',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#FF8000',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]


Mdl = LinearRegression()
Mdl.fit(X, y) 
b = Mdl.coef_
intercept = Mdl.intercept_
x = np.array([x_min, x_max])
f =  -(intercept - 0.5 + b[0] * x) / b[1]
y_hat = Mdl.predict(X) # 預 測 或 計 算 擬 合 值
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
lr=plt.plot(x, f, lw=1.5,label = '準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))),color='#484891')
lr_handle = mlines.Line2D([], [], color='#484891', linestyle='-', label='線性迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))


# Mdl = LinearRegression()
# Mdl.fit(X, y) 
# b = Mdl.coef_
# intercept = Mdl.intercept_
# x = np.array([x_min, x_max])
# f =  -(intercept - 0.5 + b[0] * x) / b[1]
# y_hat = Mdl.predict(X) # 預 測 或 計 算 擬 合 值
# y_pre = [1 if i > 0.5 else 0 for i in y_hat]
# lr=plt.plot(x, f, lw=1.5,label = 'Simple linear regression model', color='#484891')
# lr_handle = mlines.Line2D([], [], color='#484891', linestyle='-', label = 'Simple linear regression model')


Mda = LinearRegression()
x1, x2 = D[:, 0:1], D[:, 1:2]
X = np.hstack((x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
Mda.fit(X, y)
b = Mda.coef_
intercept = Mda.intercept_
f = (
lambda x: intercept
+ b[0] * x[0]
+ b[1] * x[1]
+ b[2] * x[0] * x[1]
+ b[3] * x[0] ** 2
+ b[4] * x[1] ** 2)

xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
contour_handle = mlines.Line2D([], [], color='#73BF00', linestyle='--', label='增廣迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))
contours = plt.contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))
# lr=plt.plot(x, f, lw=1.5,label = '準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))),color='#484891')
# lr_handle = mlines.Line2D([], [], color='#484891', linestyle='-', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))


Mdb = LogisticRegression()
X = D[:, 0:2]
Mdb.fit(X, y) 
intercept = Mdb.intercept_
b = Mdb.coef_
x = np.array([x_min, x_max])
f = -(intercept + b[0,0] * x) / b[0,1]
y_hat = Mdb.predict(X) 
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
logr=plt.plot(x, f, lw=1.5, color='#D9006C', label='邏輯斯迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))
logr_handle = mlines.Line2D([], [], color='#D9006C', linestyle='-', label='邏輯斯迴歸::{:.2f}%'.format(100*(np.mean(y_pre == y))))

#plt.legend()
plt.legend( handles=[a_handle,b_handle,lr_handle,contour_handle, logr_handle], loc='upper left')
plt.ylim(y_min, y_max)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
plt.grid(True)
plt.savefig('plot_14.png', format='png')
plt.show()
# Out:
# C:\Users\ChienYu\AppData\Local\Temp\ipykernel_11148\198712937.py:81: UserWarning: The following kwargs were not used by contour: 'label'
#   contours = plt.contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import ListedColormap

# 生成數據
n1, n2, n3 = 200, 200, 200
m1, m2, m3 = np.array([0, -1]), np.array([2, 4]), np.array([-3, 3])
Cov1 = np.array([[8, 0], [0, 2]])
Cov2 = np.array([[3, 1.5], [1.5, 2.5]])
Cov3 = np.array([[2, -0.7], [-0.7, 1]])

# 生成數據點
A, B, C = np.random.multivariate_normal(m1, Cov1, n1), np.random.multivariate_normal(m2, Cov2, n2), np.random.multivariate_normal(m3, Cov3, n3)
X = np.vstack((A, B, C))
y = np.hstack((np.zeros(n1), np.ones(n2), np.ones(n3)*2))

# 使用邏輯斯迴歸模型擬合數據
model = LogisticRegression()
model.fit(X, y)
# 繪製邊界線
h = .02 
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
# 繪製分類區域
plt.contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(['#CA8EFF', '#00CACA', '#7D7DFF']))

# 提取模型的係數和截距
coef = model.coef_[0]
intercept = model.intercept_

# 繪製散點圖
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=ListedColormap(['#FF60AF', '#00AEAE', '#7D7DFF']), alpha=0.7)

accuracy = model.score(X, y)
print(f"Accuracy: {accuracy * 100:.2f}%")

plt.title(f'準確率:{accuracy * 100:.2f}%')
plt.savefig('plot_18.png', format='png')

plt.show()
# Out:
# Accuracy: 92.17%

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

Mdl = LinearRegression()
Mdl.fit(X, y) 
b = Mdl.coef_
intercept = Mdl.intercept_
x = np.array([x_min, x_max])
f =  -(intercept - 0.5 + b[0] * x) / b[1]
y_hat = Mdl.predict(X) # 預 測 或 計 算 擬 合 值
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
lr=plt.plot(x, f, lw=1.5,label = '準確率:{:.2f}%'.format(100*( np.mean(y_pre == y))),color='#484891')
lr_handle = mlines.Line2D([], [], color='#484891', linestyle='-', label='準確率:{:.2f}%'.format(100*(1 - np.mean(y_pre == y))))


plt.title('Linear regression model')
plt.legend()
plt.ylim(y_min, y_max)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
plt.grid(True)
plt.savefig('plot_15.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2 = 200, 200
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#0072E3',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#FF8000',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

Mda = LinearRegression()
x1, x2 = D[:, 0:1], D[:, 1:2]
X = np.hstack((x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D[:, 2]
Mda.fit(X, y)
b = Mda.coef_
intercept = Mda.intercept_
f = (
lambda x: intercept
+ b[0] * x[0]
+ b[1] * x[1]
+ b[2] * x[0] * x[1]
+ b[3] * x[0] ** 2
+ b[4] * x[1] ** 2)

xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
contours = plt.contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*( np.mean(y_pre == y))),color='#484891')
#contour_handle = mlines.Line2D([], [], color='#73BF00', linestyle='--', label=r'Augmented Regression Model')


plt.title('Augmented Regression Model')
plt.legend(handles=[a_handle,b_handle,contour_handle])
plt.ylim(y_min, y_max)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation = 0)
plt.grid(True)
plt.savefig('plot_12.png', format='png')
plt.show()
# Out:
# C:\Users\ChienYu\AppData\Local\Temp\ipykernel_11148\791334523.py:55: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   contours = plt.contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*( np.mean(y_pre == y))),color='#484891')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines

n1, n2 = 200, 200
m1, m2 = np.array([-3, 2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean=m1, cov=Cov1)
mvn2 = multivariate_normal(mean=m2, cov=Cov2)
A, B = mvn1.rvs(n1, random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D = np.hstack((X, y.reshape(-1, 1)))

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1

Idx = (D[:, 2] == 0)
a = plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha=0.5, label='Group A')
a_handle = mlines.Line2D([], [], color='#0080FF', alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group A')
Idx = (D[:, 2] == 1)
b = plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha=0.5, label='Group B')
b_handle = mlines.Line2D([], [], color='#FF8000', alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]

Mdb = LogisticRegression()
X = D[:, 0:2]
Mdb.fit(X, y)
intercept = Mdb.intercept_
b = Mdb.coef_
x = np.array([x_min, x_max])
f = -(intercept + b[0, 0] * x) / b[0, 1]
y_hat = Mdb.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
logr = plt.plot(x, f, lw=1.5, label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))), color='#D9006C')

plt.title('Logistic Regression Model')
plt.legend(handles=[a_handle, b_handle, logr[0]], loc='upper left')
plt.ylim(y_min, y_max)
plt.xlabel('$X_1$')
plt.ylabel('$X_2$', rotation=0)
plt.grid(True)
plt.savefig('plot_13.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
n1, n2,n3 = 200, 200,200
m1, m2,m3 = np.array([0, -1]), np.array([2,4]),np.array([-3, 3])
Cov1 = np.array([[8, 0], [0, 2]])
Cov2 = np.array([[3, 1.5], [1.5, 2.5]])
Cov3 = np.array([[2, -0.7], [-0.7, 1]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
#這個陣列代表二維空間中的共變異數矩陣
# 對於二維資料，共變異數矩陣描述了兩個變數之間的方差和共變異數
# 對角線上的值代表每個變數自身的方差（第一個變數的方差為10，第二個變數的方差為1）
# 非對角線上的值表示兩個變數之間的共變異數（這裡為0，表示兩個變數之間沒有線性相關性）
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
mvn3 = multivariate_normal(mean = m3, cov = Cov3)
A, B,C = mvn1.rvs(n1,random_state=123), mvn2.rvs(n2, random_state=123),mvn3.rvs(n3, random_state=123)
X = np.vstack((A, B, C))
y = np.hstack((np.zeros(n1), np.ones(n2),np.ones(n3)*2))
D=np.hstack((X,y.reshape(-1,1)))
x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points


Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.6, label ='Group A', color='#FF60AF')
a_handle = mlines.Line2D([], [], color='#FF60AF',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.6, label = 'Group B', color='#00AEAE')
b_handle=mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')
Idx = (D[:,2]==2)
c=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.6, label = 'Group C', color='#7D7DFF')
c_handle=mlines.Line2D([], [], color='#7D7DFF',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group C')
n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]


plt.grid(True)
plt.legend()
plt.savefig('plot_10.png', format='png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import ListedColormap

# 生成數據
n1, n2, n3 = 200, 200, 200
m1, m2, m3 = np.array([0, -1]), np.array([2, 4]), np.array([-3, 3])
Cov1 = np.array([[8, 0], [0, 2]])
Cov2 = np.array([[3, 1.5], [1.5, 2.5]])
Cov3 = np.array([[2, -0.7], [-0.7, 1]])

# 生成數據點
A, B, C = np.random.multivariate_normal(m1, Cov1, n1), np.random.multivariate_normal(m2, Cov2, n2), np.random.multivariate_normal(m3, Cov3, n3)
X = np.vstack((A, B, C))
y = np.hstack((np.zeros(n1), np.ones(n2), np.ones(n3)*2))

# 使用邏輯斯迴歸模型擬合數據
model = LogisticRegression()
model.fit(X, y)
# 繪製邊界線
h = .02 
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
# 繪製分類區域
plt.contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(['#CA8EFF', '#00CACA', '#7D7DFF']))

# 提取模型的係數和截距
coef = model.coef_[0]
intercept = model.intercept_

# 繪製散點圖
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=ListedColormap(['#FF60AF', '#00AEAE', '#7D7DFF']), alpha=0.7)

plt.savefig('plot_18.png', format='png')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
import sklearn.model_selection as ms

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 設置字體為中文字體，這裡使用的是SimHei字體，也可以根據需要更改為其他中文字體
plt.rcParams['axes.unicode_minus'] = False

n1, n2 = 400, 400
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))
D_train, D_test = ms.train_test_split(D, test_size=0.2, random_state=0)
s = 30 

fig,ax = plt.subplots(2,1,figsize=(8,8))
fig= fig.subplots_adjust(hspace=0.3) 
x_min, x_max = D_train[:, 0].min() - 1, D_train[:, 0].max() + 1
y_min, y_max = D_train[:, 1].min() - 1, D_train[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points
Idx = (D_train[:,2]==0)
a=ax[0].plot(D_train[Idx, 0], D_train[Idx, 1], 'o', alpha = 0.5, label ='Group A', color='#0066CC')
a_handle = mlines.Line2D([], [], color='#0066CC',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group A')
Idx = (D_train[:,2]==1)
b=ax[0].plot(D_train[Idx,0], D_train[Idx,1],'o', alpha = 0.5, label = 'Group B', color='#FF8000')
b_handle=mlines.Line2D([], [], color='#FF8000',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group B')
n = len(D_train[:, 0])
X = D_train[:, 0:2]
y = D_train[:, 2]


Mdl = LinearRegression()
Mdl.fit(X, y) 
b = Mdl.coef_
intercept = Mdl.intercept_
x = np.array([x_min, x_max])
f =  -(intercept - 0.5 + b[0] * x) / b[1]
y_hat = Mdl.predict(X) # 預 測 或 計 算 擬 合 值
y_pre = [1 if i > 0.5 else 0 for i in y_hat]

lr=ax[0].plot(x, f, lw=1.5, color='#484891')
lr=ax[1].plot(x, f, lw=1.5, color='#484891')
lr_handle = mlines.Line2D([], [], color='#484891', linestyle='-', label='線性迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))


Mda = LinearRegression()
x1, x2 = D_train[:, 0:1], D_train[:, 1:2]
X = np.hstack((x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y = D_train[:, 2]
Mda.fit(X, y)
b = Mda.coef_
intercept = Mda.intercept_
f = (
lambda x: intercept
+ b[0] * x[0]
+ b[1] * x[1]
+ b[2] * x[0] * x[1]
+ b[3] * x[0] ** 2
+ b[4] * x[1] ** 2)

xx = np.linspace(x_min, x_max, nx)
yy = np.linspace(y_min, y_max, ny)
XX, YY = np.meshgrid(xx, yy)
Z = f([XX, YY])
Mda.fit(X, y)
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
contours = ax[0].contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))
contours = ax[1].contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))
contour_handle = mlines.Line2D([], [], color='#73BF00', linestyle='--', label='增廣迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))


Mdb = LogisticRegression()
X = D_train[:, 0:2]
Mdb.fit(X, y) 
intercept = Mdb.intercept_
b = Mdb.coef_
x = np.array([x_min, x_max])
f = -(intercept + b[0,0] * x) / b[0,1]
y_hat = Mdb.predict(X) 
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
logr=ax[0].plot(x, f, lw=1.5,label = '{:.2f}%'.format(100*(1 - np.mean(y_pre == y))), color='#D9006C')
logr=ax[1].plot(x, f, lw=1.5,label = '{:.2f}%'.format(100*(1 - np.mean(y_pre == y))), color='#D9006C')
logr_handle = mlines.Line2D([], [], color='#D9006C', linestyle='-', label='邏輯斯迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))

ax[0].set_title(r'訓練資料')
ax[0].legend( handles=[a_handle,b_handle,lr_handle,contour_handle, logr_handle], loc='upper left',bbox_to_anchor=(1.02, 1), borderaxespad=0)
ax[0].set_ylim(y_min, y_max)
ax[0].set_xlabel('$X_1$')
ax[0].set_ylabel('$X_2$', rotation = 0)
ax[0].grid(True)

x_min, x_max = D_test[:, 0].min() - 1, D_test[:, 0].max() + 1
y_min, y_max = D_test[:, 1].min() - 1, D_test[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points
Idx = (D_test[:,2]==0)
a=ax[1].plot(D_test[Idx, 0], D_test[Idx, 1], 'o', alpha = 0.5, label ='Group A', color='#0066CC')
a_handle = mlines.Line2D([], [], color='#0066CC',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group A')
Idx = (D_test[:,2]==1)
b=ax[1].plot(D_test[Idx,0], D_test[Idx,1],'o', alpha = 0.5, label = 'Group B', color='#FF8000')
b_handle=mlines.Line2D([], [], color='#FF8000',alpha=0.5, marker='o', linestyle='None', markersize=6, label='Group B')


n = len(D_test[:, 0])
X = D_test[:, 0:2]
y = D_test[:, 2]


y_hat = Mdl.predict(X) # 預 測 或 計 算 擬 合 值
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
lr_handle = mlines.Line2D([], [], color='#484891', linestyle='-', label='線性迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))


x1, x2 = D_test[:, 0:1], D_test[:, 1:2]
X = np.hstack((x1, x2, x1 * x2, x1 ** 2, x2 ** 2))
y_hat = Mda.predict(X)
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
contour_handle = mlines.Line2D([], [], color='#73BF00', linestyle='--', label='增廣迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))


X = D_test[:, 0:2]
y_hat = Mdb.predict(X) 
y_pre = [1 if i > 0.5 else 0 for i in y_hat]
logr_handle = mlines.Line2D([], [], color='#D9006C', linestyle='-', label='邏輯斯迴歸:準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))

ax[1].set_title(r'測試資料')
ax[1].legend( handles=[a_handle,b_handle,lr_handle,contour_handle, logr_handle], loc='upper left',bbox_to_anchor=(1.02, 1), borderaxespad=0)
ax[1].set_ylim(y_min, y_max)
ax[1].set_xlabel('$X_1$')
ax[1].set_ylabel('$X_2$', rotation = 0)
ax[1].grid(True)

#plt.savefig('plot_19.png', format='png')
plt.savefig('plot_19.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\ChienYu\AppData\Local\Temp\ipykernel_11148\3791278184.py:76: UserWarning: The following kwargs were not used by contour: 'label'
#   contours = ax[0].contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))
# C:\Users\ChienYu\AppData\Local\Temp\ipykernel_11148\3791278184.py:77: UserWarning: The following kwargs were not used by contour: 'label'
#   contours = ax[1].contour(XX, YY, Z, levels = [0.5], colors='#73BF00', linestyles='--', label='準確率:{:.2f}%'.format(100*(np.mean(y_pre == y))))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import matplotlib.lines as mlines
import sklearn.model_selection as ms

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 設置字體為中文字體，這裡使用的是SimHei字體，也可以根據需要更改為其他中文字體
plt.rcParams['axes.unicode_minus'] = False

n1, n2 = 400, 400
m1, m2 = np.array([-3,2]), np.array([3, 2])
Cov1 = np.array([[10, 1.2], [1.2, 2.3]])
Cov2 = np.array([[4, -0.9], [-0.9, 2]])
mvn1 = multivariate_normal(mean = m1, cov = Cov1)
mvn2 = multivariate_normal(mean = m2, cov = Cov2)
A, B = mvn1.rvs(n1,random_state=55), mvn2.rvs(n2, random_state=55)
X = np.vstack((A, B))
y = np.hstack((np.zeros(n1), np.ones(n2)))
D=np.hstack((X,y.reshape(-1,1)))
D_train, D_test = ms.train_test_split(D, test_size=0.2, random_state=0)

x_min, x_max = D[:, 0].min() - 1, D[:, 0].max() + 1
y_min, y_max = D[:, 1].min() - 1, D[:, 1].max() + 1
nx, ny = 200, 200 # number of grid points

Idx = (D[:,2]==0)
a=plt.plot(D[Idx, 0], D[Idx, 1], 'o', alpha = 0.5, label ='Group A')
a_handle = mlines.Line2D([], [], color='#00AEAE',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group A')
Idx = (D[:,2]==1)
b=plt.plot(D[Idx,0], D[Idx,1],'o', alpha = 0.5, label = 'Group B')
b_handle=mlines.Line2D([], [], color='#A6A6D2',alpha=0.5, marker='o', linestyle='None', markersize=10, label='Group B')

n = len(D[:, 0])
X = D[:, 0:2]
y = D[:, 2]


plt.grid(True)
plt.legend()
plt.savefig('plot_20.png', format='png')
plt.show()

plt.show()

# %%
from matplotlib.font_manager import fontManager
A=sorted(fontManager.get_font_names())
